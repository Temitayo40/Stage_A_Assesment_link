# %%
import pandas as pd
from io import StringIO

# %%
df = pd.read_csv('FoodBalance.csv', encoding='latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df[['Y2014', 'Y2018']].count()
# Out:
# Y2014    59354
# Y2018    59507
# dtype: int64

# %%
df.loc[250]
# Out:
# Area Code                       4
# Area                      Algeria
# Item Code                    2543
# Item            Sweeteners, Other
# Element Code                 5072
# Element           Stock Variation
# Unit                  1000 tonnes
# Y2014                        47.0
# Y2015                        53.0
# Y2016                        68.0
# Y2017                        60.0
# Y2018                        90.0
# Name: 250, dtype: object

# %%
year_2014 =df.Y2014.sum().round()
year_2016 =df.Y2016.sum().round()

print('The total sum of death cases in year 2014 and 2016 are {} and {} respectively'.format(year_2014, year_2016))
# Out:
# The total sum of death cases in year 2014 and 2016 are 7965086.0 and 8112473.0 respectively

# %%
  df1 =   df[['Y2014', 'Y2015', 'Y2016', 'Y2017']].head(20) > 2000 
df1
# Out:
#     Y2014  Y2015  Y2016  Y2017
# 0    True   True   True   True
# 1   False  False  False  False
# 2    True   True   True   True
# 3   False  False  False  False
# 4   False  False  False  False
# 5    True   True   True   True
# 6   False  False  False  False
# 7   False  False  False  False
# 8   False  False  False  False
# 9   False  False  False  False
# 10  False  False  False  False
# 11   True   True   True   True
# 12   True   True   True   True
# 13  False  False  False  False
# 14  False  False  False  False
# 15   True   True   True   True
# 16   True   True   True   True
# 17  False  False  False  False
# 18  False  False  False  False
# 19  False  False  False  False

# %%
df[df1]
# Out:
#        Area Code Area  Item Code Item  Element Code Element Unit    Y2014  \
# 0            NaN  NaN        NaN  NaN           NaN     NaN  NaN  38924.0
# 1            NaN  NaN        NaN  NaN           NaN     NaN  NaN      NaN
# 2            NaN  NaN        NaN  NaN           NaN     NaN  NaN   3377.0
# 3            NaN  NaN        NaN  NaN           NaN     NaN  NaN      NaN
# 4            NaN  NaN        NaN  NaN           NaN     NaN  NaN      NaN
# ...          ...  ...        ...  ...           ...     ...  ...      ...
# 60938        NaN  NaN        NaN  NaN           NaN     NaN  NaN      NaN
# 60939        NaN  NaN        NaN  NaN           NaN     NaN  NaN      NaN
# 60940        NaN  NaN        NaN  NaN           NaN     NaN  NaN      NaN
# 60941        NaN  NaN        NaN  NaN           NaN     NaN  NaN      NaN
# 60942        NaN  NaN        NaN  NaN           NaN     NaN  NaN      NaN
#
#          Y2015    Y2016    Y2017  Y2018
# ...

# %%
per_cent = 2.0

# %%
Y_cent = df[df.Y2014 / df.Y2018  >  per_cent]
Y_cent
# Out:
#        Area Code      Area  Item Code                  Item  Element Code  \
# 48             4   Algeria       2805     Rice and products          5521
# 59             4   Algeria       2513   Barley and products          5611
# 98             4   Algeria       2516                  Oats          5611
# 117            4   Algeria       2518  Sorghum and products          5611
# 140            4   Algeria       2520        Cereals, Other           674
# ...          ...       ...        ...                   ...           ...
# 60938        181  Zimbabwe       2899         Miscellaneous          5142
# 60939        181  Zimbabwe       2899         Miscellaneous           645
# 60940        181  Zimbabwe       2899         Miscellaneous           664
# 60941        181  Zimbabwe       2899         Miscellaneous           674
# 60942        181  Zimbabwe       2899         Miscellaneous           684
#
#                                       Element             Unit   Y2014  \
# ...

# %%
df['per_cent'] = df.Y2014 / df.Y2015
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.sort_values(['Y2014', 'Y2018'], ascending= [False,True] ).head(10)
# Out:
#        Area Code                         Area  Item Code  \
# 42973        159                      Nigeria       2501
# 43129        159                      Nigeria       2907
# 43133        159                      Nigeria       2907
# 19008        238                     Ethiopia       2501
# 16236         59                        Egypt       2501
# 43148        159                      Nigeria       2532
# 43145        159                      Nigeria       2532
# 49822        202                 South Africa       2501
# 56680        215  United Republic of Tanzania       2501
# 43140        159                      Nigeria       2907
#
#                        Item  Element Code                        Element  \
# 42973            Population           511  Total Population - Both sexes
# 43129         Starchy Roots          5511                     Production
# 43133         Starchy Roots          5301       Domestic supply quantity
# ...

# %%
area_algeria = df[df.Area == 'Zimbabwe']
area_algeria
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 59550        181  Zimbabwe       2501     Population           511
# 59551        181  Zimbabwe       2501     Population          5301
# 59552        181  Zimbabwe       2901    Grand Total           664
# 59553        181  Zimbabwe       2901    Grand Total           674
# 59554        181  Zimbabwe       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 59550           Total Population - Both sexes     1000 persons  13587.00
# ...

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
total_sum = df.groupby('Item')[['Y2014', 'Y2017']].sum()
total_sum
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
df.Y2015.describe().round(3)
# Out:
# count     59395.000
# mean        135.236
# std        1603.404
# min       -3161.000
# 25%           0.000
# 50%           0.080
# 75%           8.460
# max      181137.000
# Name: Y2015, dtype: float64

# %%
miss = df.Y2016.isna().sum()
miss
# Out:
# 1535

# %%
percentage = (miss / 6093) * 100
percentage
# Out:
# 25.192844247497128

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.groupby('Element Code')[['Y2014','Y2015','Y2016','Y2017']].sum()
# Out:
#                    Y2014       Y2015       Y2016       Y2017
# Element Code
# 511           1031585.00  1058081.00  1085107.00  1112641.00
# 645             49650.63    49345.13    48985.28    48690.04
# 664            454257.00   453383.00   451810.00   454681.00
# 674             11836.46    11833.95    11779.69    11842.45
# 684             10225.56    10235.74    10102.77    10253.84
# 5072            58749.83    34910.99    33140.12    54316.91
# 5123           153223.00   155439.00   157787.00   160614.00
# 5131           282923.00   287929.00   280631.00   292836.00
# 5142          1212332.49  1232361.10  1247022.17  1258888.28
# 5154            78718.13    66254.41    69563.68    91645.97
# 5170            30149.00    30045.00    37224.00    35500.00
# 5171              416.00      349.00       89.00       91.00
# 5301          1996716.35  2021493.55  2044842.70  2088198.10
# 5511          1931287.75  1947019.39  1943537.15  2030056.89
# ...

# %%
df.groupby('Element')[['Y2014','Y2015','Y2016','Y2017']].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
df.groupby(['Area', 'Element'])['Y2018' ].sum().head(40)
# Out:
# Area     Element
# Algeria  Domestic supply quantity                  90023.42
#          Export Quantity                             811.54
#          Fat supply quantity (g/capita/day)          309.09
#          Feed                                      10668.00
#          Food                                      63736.33
#          Food supply (kcal/capita/day)             13288.00
#          Food supply quantity (kg/capita/yr)        1509.28
#          Import Quantity                           36238.29
#          Losses                                     7708.00
#          Other uses (non-food)                      3970.08
#          Processing                                 2479.00
#          Production                                60766.67
#          Protein supply quantity (g/capita/day)      367.28
#          Residuals                                   630.00
#          Seed                                        825.00
# ...

# %%
df.groupby('Area')
